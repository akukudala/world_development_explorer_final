# %% [markdown]
# <a href="https://colab.research.google.com/github/akukudala/world_development_explorer_final/blob/main/wdx_final/wdx_analysis_partB_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Name: Akshitha Kukudala
# * Date: 4/08/2022
#
# # Analyzing the percentages of female population (age 15-19) education stats over the years 2010 to 2015
# ## Indicators to consider
# * No Education
# * Completed Primary Education
# * Completed Secondary Education

# %% [markdown]
# The primary motive of this project is to focus on Female Primary and Secondary education in East Asia & Pacific region.
# Many governments publish statistics showing how well their education systems are working and improving,
# with data on enrollment and completion.
# Monitoring progress toward national and global education targets helps allocate resources more efficiently and make quality learning opportunities accessible to all.
# Better-quality education leads to an empowered citizenry and a more productive labor force. We will also analyze the mentioned region with the other regions in the world as per data derived from
# World Development Explorer. The reason why most of the females in the world are left uneducationed is due to their financial background. Let us consider the Financial states of the region to compare
# the correlation between the education and the income.

# %% [markdown]
# - **Data Source:** World Development Explorer ([worlddev.xyz](https://))
# - **Regions Analyzed:** East Asia & Pacific
# - **Years considered:** 2010-2015

# %%
import pandas as pd
import plotly.express as px

# %%
csv_file = "https://raw.githubusercontent.com/akukudala/world_development_explorer/main/wdi_data_3_indicators.csv"

# %%
df = pd.read_csv(csv_file, index_col=0)

df.sample(5)
# Out:
#      Year  value                indicator Country Code       Country Name  \
# 190  2010   3.40      BAR.NOED.1519.FE.ZS          DEU            Germany
# 321  2010  11.39  BAR.SEC.CMPT.1519.FE.ZS          CZE     Czech Republic
# 304  2010  19.74  BAR.SEC.CMPT.1519.FE.ZS          BRN  Brunei Darussalam
# 49   2010  34.93  BAR.PRM.CMPT.1519.FE.ZS          GTM          Guatemala
# 203  2010  18.53      BAR.NOED.1519.FE.ZS          IRQ               Iraq
#
#                          Region         Income Group    Lending Type
# 190       Europe & Central Asia          High income  Not classified
# 321       Europe & Central Asia          High income  Not classified
# 304         East Asia & Pacific          High income  Not classified
# 49   Latin America & Caribbean   Upper middle income            IBRD
# 203  Middle East & North Africa  Upper middle income            IBRD

# %% [markdown]
# The important analyzation factors are to find the answers for the below questions.
#
# * What are the leading countries in no education, primary and secondary education seperately?
# * How does the financial situation impacting the female education?
# * What position does East Asia & Pacific is in comparison with other regions?

# %%
df_noed = df.query("indicator == 'BAR.NOED.1519.FE.ZS'").query("Region == 'East Asia & Pacific'")
df_noed = df_noed.sort_values(by= "value", ascending= False)
df_noed.sample(5)
# Out:
#      Year  value            indicator Country Code      Country Name  \
# 259  2010   2.02  BAR.NOED.1519.FE.ZS          SGP         Singapore
# 245  2010  40.67  BAR.NOED.1519.FE.ZS          PNG  Papua New Guinea
# 185  2010   0.32  BAR.NOED.1519.FE.ZS          FJI              Fiji
# 212  2010   0.05  BAR.NOED.1519.FE.ZS          KOR       Korea, Rep.
# 149  2010   0.10  BAR.NOED.1519.FE.ZS          AUS         Australia
#
#                   Region         Income Group    Lending Type
# 259  East Asia & Pacific          High income  Not classified
# 245  East Asia & Pacific  Lower middle income           Blend
# 185  East Asia & Pacific  Upper middle income           Blend
# 212  East Asia & Pacific          High income  Not classified
# 149  East Asia & Pacific          High income  Not classified

# %%
import plotly

fig = px.bar(
    data_frame= df_noed,
    x= "Country Name",
    labels={"value":"2010 Barro-Lee: Percentage of Female population age 15-19 with no education"},
    y= "value",
    color= "Country Name",
    height= 700,
    template=list(plotly.io.templates.keys())[5],
    title= " Percentage of Female population age 15-19 with no education in East Asia & Pacific "
)
fig = fig.update_layout(showlegend= False)

# %% [markdown]
# ## Female population (age 15-19) over the years 2010 to 2015 with No Education
# Firstly, let us observe the female population with no education among various countries

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8d183ee5-d6b8-4426-a327-b44d643e55f3" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d183ee5-d6b8-4426-a327-b44d643e55f3")) {                    Plotly.newPlot(                        "8d183ee5-d6b8-4426-a327-b44d643e55f3",                        [{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with no education=%{y}<extra></extra>","legendgroup":"Vietnam","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Vietnam","offsetgroup":"Vietnam","orientation":"v","showlegend":true,"textposition":"auto","x":["Vietnam"],"xaxis":"x","y":[57.77],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with no education=%{y}<extra></extra>","legendgroup":"Papua New Guinea","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Papua New Guinea","offsetgroup":"Papua New Guinea","orientation":"v","showlegend":true,"textposition":"auto","x":["Papua New Guinea"],"xaxis":"x","y":[40.67],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with no education=%{y}<extra></extra>","legendgroup":"Lao PDR","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Lao PDR","offsetgroup":"Lao PDR","orientation":"v","showlegend":true,"textposition":"auto","x":["Lao PDR"],"xaxis":"x","y":[25.41],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with no education=%{y}<extra></extra>","legendgroup":"Brunei Darussalam","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Brunei Darussalam","offsetgroup":"Brunei Darussalam","orientation":"v","showlegend":true,"textposition":"auto","x":["Brunei Darussalam"],"xaxis":"x","y":[20.1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with no education=%{y}<extra></extra>","legendgroup":"Cambodia","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Cambodia","offsetgroup":"Cambodia","orientation":"v","showlegend":true,"textposition":"auto","x":["Cambodia"],"xaxis":"x","y":[7.86],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with no education=%{y}<extra></extra>","legendgroup":"New Zealand","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"New Zealand","offsetgroup":"New Zealand","orientation":"v","showlegend":true,"textposition":"auto","x":["New Zealand"],"xaxis":"x","y":[4.68],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with no education=%{y}<extra></extra>","legendgroup":"Thailand","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Thailand","offsetgroup":"Thailand","orientation":"v","showlegend":true,"textposition":"auto","x":["Thailand"],"xaxis":"x","y":[2.47],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with no education=%{y}<extra></extra>","legendgroup":"Mongolia","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Mongolia","offsetgroup":"Mongolia","orientation":"v","showlegend":true,"textposition":"auto","x":["Mongolia"],"xaxis":"x","y":[2.32],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with no education=%{y}<ex ...

# %%
df_noed.shape
# Out:
# (21, 8)

# %%
df_pcmpt = df.query("indicator == 'BAR.PRM.CMPT.1519.FE.ZS'").query("Region == 'East Asia & Pacific'")
df_pcmpt = df_pcmpt.sort_values(by= "value", ascending= False)
df_pcmpt.sample(5)
# Out:
#      Year  value                indicator Country Code Country Name  \
# 19   2010  39.93  BAR.PRM.CMPT.1519.FE.ZS          KHM     Cambodia
# 71   2010  25.56  BAR.PRM.CMPT.1519.FE.ZS          LAO      Lao PDR
# 95   2010   0.06  BAR.PRM.CMPT.1519.FE.ZS          NZL  New Zealand
# 64   2010   1.89  BAR.PRM.CMPT.1519.FE.ZS          JPN        Japan
# 115  2010   1.55  BAR.PRM.CMPT.1519.FE.ZS          SGP    Singapore
#
#                   Region         Income Group    Lending Type
# 19   East Asia & Pacific  Lower middle income             IDA
# 71   East Asia & Pacific  Lower middle income             IDA
# 95   East Asia & Pacific          High income  Not classified
# 64   East Asia & Pacific          High income  Not classified
# 115  East Asia & Pacific          High income  Not classified

# %%
import plotly
fig = px.bar(
    data_frame= df_pcmpt,
    x= "Country Name",
    labels={"value":"2010 Barro-Lee: Percentage of Female population age 15-19 with primary schooling, Completed Primary"},
    y= "value",
    color= "Country Name",
    height= 700,
    template=list(plotly.io.templates.keys())[5],
    title= " Percentage of Female population age 15-19 with Primary education in East Asia & Pacific "
)

fig = fig.update_layout(showlegend= False)

# %% [markdown]
# ## Female population (age 15-19) over the years 2010 to 2015 with Primary Education Completion
# Countries with Female Population % who has completed Primary education

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3268dedc-a9b3-45ed-a81d-5216f9c885b8" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3268dedc-a9b3-45ed-a81d-5216f9c885b8")) {                    Plotly.newPlot(                        "3268dedc-a9b3-45ed-a81d-5216f9c885b8",                        [{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with primary schooling, Completed Primary=%{y}<extra></extra>","legendgroup":"Myanmar","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Myanmar","offsetgroup":"Myanmar","orientation":"v","showlegend":true,"textposition":"auto","x":["Myanmar"],"xaxis":"x","y":[57.4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with primary schooling, Completed Primary=%{y}<extra></extra>","legendgroup":"Papua New Guinea","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Papua New Guinea","offsetgroup":"Papua New Guinea","orientation":"v","showlegend":true,"textposition":"auto","x":["Papua New Guinea"],"xaxis":"x","y":[43.3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with primary schooling, Completed Primary=%{y}<extra></extra>","legendgroup":"Cambodia","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Cambodia","offsetgroup":"Cambodia","orientation":"v","showlegend":true,"textposition":"auto","x":["Cambodia"],"xaxis":"x","y":[39.93],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with primary schooling, Completed Primary=%{y}<extra></extra>","legendgroup":"Indonesia","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Indonesia","offsetgroup":"Indonesia","orientation":"v","showlegend":true,"textposition":"auto","x":["Indonesia"],"xaxis":"x","y":[27.03],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with primary schooling, Completed Primary=%{y}<extra></extra>","legendgroup":"Lao PDR","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Lao PDR","offsetgroup":"Lao PDR","orientation":"v","showlegend":true,"textposition":"auto","x":["Lao PDR"],"xaxis":"x","y":[25.56],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with primary schooling, Completed Primary=%{y}<extra></extra>","legendgroup":"Australia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Australia","offsetgroup":"Australia","orientation":"v","showlegend":true,"textposition":"auto","x":["Australia"],"xaxis":"x","y":[18.53],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with primary schooling, Completed Primary=%{y}<extra></extra>","legendgroup":"Brunei Darussalam","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Brunei Darussalam","offsetgroup":"Brunei Darussalam","orientation":"v","showlegend":true,"textposition":"auto","x":["Brunei Darussalam"],"xaxis":"x","y":[17.47],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with primary schooling, Completed Primary=%{y}<extra></extra>","legendgroup":"Macao SAR, China","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Macao SAR, China","offsetgroup":"Macao SAR, China","orientation":"v","showlegend":true,"textposition":"auto ...

# %%
df_pcmpt.shape
# Out:
# (21, 8)

# %%
df_scmpt = df.query("indicator == 'BAR.SEC.CMPT.1519.FE.ZS'").query("Region == 'East Asia & Pacific'")
df_scmpt = df_scmpt.sort_values(by= "value", ascending= False)
df_scmpt.sample(5)
# Out:
#      Year  value                indicator Country Code      Country Name  \
# 345  2010  16.73  BAR.SEC.CMPT.1519.FE.ZS          IDN         Indonesia
# 366  2010  34.39  BAR.SEC.CMPT.1519.FE.ZS          MAC  Macao SAR, China
# 428  2010  11.31  BAR.SEC.CMPT.1519.FE.ZS          VNM           Vietnam
# 312  2010  45.25  BAR.SEC.CMPT.1519.FE.ZS          CHN             China
# 389  2010   5.60  BAR.SEC.CMPT.1519.FE.ZS          PNG  Papua New Guinea
#
#                   Region         Income Group    Lending Type
# 345  East Asia & Pacific  Lower middle income            IBRD
# 366  East Asia & Pacific          High income  Not classified
# 428  East Asia & Pacific  Lower middle income            IBRD
# 312  East Asia & Pacific  Upper middle income            IBRD
# 389  East Asia & Pacific  Lower middle income           Blend

# %%
import plotly
fig = px.bar(
    data_frame= df_scmpt,
    x= "Country Name",
    labels={"value":"2010 Barro-Lee: Percentage of Female population age 15-19 with secondary schooling, Completed Secondary"},
    y= "value",
    color= "Country Name",
    height= 700,
    template=list(plotly.io.templates.keys())[5],
    title= " Percentage of Female population age 15-19 with Secondary education in East Asia & Pacific",
    
)

fig = fig.update_layout(showlegend= False)

# %% [markdown]
# ## Female population (age 15-19) over the years 2010 to 2015 with Secondary Education Completion
#
# Countries with Female Population % who has completed Secondary education

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1a795037-f969-4a32-b99b-e2b9e9207df5" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a795037-f969-4a32-b99b-e2b9e9207df5")) {                    Plotly.newPlot(                        "1a795037-f969-4a32-b99b-e2b9e9207df5",                        [{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with secondary schooling, Completed Secondary=%{y}<extra></extra>","legendgroup":"Hong Kong SAR, China","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Hong Kong SAR, China","offsetgroup":"Hong Kong SAR, China","orientation":"v","showlegend":true,"textposition":"auto","x":["Hong Kong SAR, China"],"xaxis":"x","y":[81.13],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with secondary schooling, Completed Secondary=%{y}<extra></extra>","legendgroup":"Korea, Rep.","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Korea, Rep.","offsetgroup":"Korea, Rep.","orientation":"v","showlegend":true,"textposition":"auto","x":["Korea, Rep."],"xaxis":"x","y":[74.19],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with secondary schooling, Completed Secondary=%{y}<extra></extra>","legendgroup":"Singapore","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Singapore","offsetgroup":"Singapore","orientation":"v","showlegend":true,"textposition":"auto","x":["Singapore"],"xaxis":"x","y":[72.53],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with secondary schooling, Completed Secondary=%{y}<extra></extra>","legendgroup":"Japan","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Japan","offsetgroup":"Japan","orientation":"v","showlegend":true,"textposition":"auto","x":["Japan"],"xaxis":"x","y":[69.97],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with secondary schooling, Completed Secondary=%{y}<extra></extra>","legendgroup":"Malaysia","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Malaysia","offsetgroup":"Malaysia","orientation":"v","showlegend":true,"textposition":"auto","x":["Malaysia"],"xaxis":"x","y":[65.05],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with secondary schooling, Completed Secondary=%{y}<extra></extra>","legendgroup":"Tonga","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Tonga","offsetgroup":"Tonga","orientation":"v","showlegend":true,"textposition":"auto","x":["Tonga"],"xaxis":"x","y":[62.92],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with secondary schooling, Completed Secondary=%{y}<extra></extra>","legendgroup":"Fiji","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Fiji","offsetgroup":"Fiji","orientation":"v","showlegend":true,"textposition":"auto","x":["Fiji"],"xaxis":"x","y":[51.18],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Barro-Lee: Percentage of Female population age 15-19 with secondary schooling, Completed Secondary=%{y}<extra></extra>","legendgroup":"China","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"v","showlegend":true,"textposition":"auto","x":["China"],"xaxis":"x","y":[45.25],"ya ...

# %% [markdown]
# In the above three charts, we have seen different countries in leading for no education, primary and secondary completion. Now, let us consider 3 different Income Groups and filter the female education % financial status wise and observe how the financial status influence the education of an individual.

# %%
df_noed.groupby('Income Group')
df_noed2 = df_noed.groupby(['Income Group']).agg(
    Hours_Mean = ('value', 'mean'))

df_noed2
# Out:
#                      Hours_Mean
# Income Group
# High income             3.50250
# Lower middle income    16.99625
# Upper middle income     1.04200

# %%
dfnoed3 = df_noed2.reset_index()

# %%
dfnoed3
# Out:
#           Income Group  Hours_Mean
# 0          High income     3.50250
# 1  Lower middle income    16.99625
# 2  Upper middle income     1.04200

# %%
fig = px.pie(
    dfnoed3, values='Hours_Mean', names="Income Group",
  template=list(plotly.io.templates.keys())[5]
)
fig.update_traces(textposition='inside',hoverinfo="label+name")

fig.update_traces(text = dfnoed3['Income Group'].value_counts(), textinfo = 'label+percent')



indicator_dict = dict(
  font=dict(color="White",size=14),
  x=0.5,
  y=0,
  opacity=0.5,
  showarrow=False,
  text="Percentage of Female population age 15-19 with No education in East Asia & Pacific grouped by Income",
  textangle=0,
  xanchor='center',
  yanchor="top",
  xref="paper",
  yref="paper"
)

fig = fig.add_annotation(indicator_dict)

# %% [markdown]
# ## No Education grouping by Incomes
# While it is obvious that lower middle income population has the highest illeteracy rates, it is surprising to the high income to take the second place.

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f585852d-9da6-400d-86fe-9ceeee3fa2e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f585852d-9da6-400d-86fe-9ceeee3fa2e9")) {                    Plotly.newPlot(                        "f585852d-9da6-400d-86fe-9ceeee3fa2e9",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Income Group=%{label}<br>Hours_Mean=%{value}<extra></extra>","labels":["High income","Lower middle income","Upper middle income"],"legendgroup":"","name":"","showlegend":true,"values":[3.5025,16.99625,1.042],"type":"pie","hoverinfo":"label+name","textposition":"inside","text":[1,1,1],"textinfo":"label+percent"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"ma ...

# %%
df_pcmpt.groupby('Income Group')
df_pcmpt2 = df_pcmpt.groupby(['Income Group']).agg(
    Hours_Mean = ('value', 'mean'))

df_pcmpt2
# Out:
#                      Hours_Mean
# Income Group
# High income             6.38375
# Lower middle income    27.67375
# Upper middle income     5.94600

# %%
df_pcmpt3=df_pcmpt2.reset_index()

# %%
fig = px.pie(
    df_pcmpt3, values='Hours_Mean', names="Income Group",
  template=list(plotly.io.templates.keys())[5]
)
fig.update_traces(textposition='inside',hoverinfo="label+name")

fig.update_traces(text = df_pcmpt3['Income Group'].value_counts(), textinfo = 'label+percent')


indicator_dict = dict(
  font=dict(color="White",size=14),
  x=0.5,
  y=0,
  opacity=0.5,
  showarrow=False,
  text="Percentage of Female population age 15-19 with Primary education in East Asia & Pacific grouped by Income",
  textangle=0,
  xanchor='center',
  yanchor="top",
  xref="paper",
  yref="paper"
)

fig = fig.add_annotation(indicator_dict)

# %% [markdown]
# ##Primary Education grouping by Incomes
# Lower middle income is leading in the primary education too. Despite of earning less, these countries are giving importance for the primary education to female population

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8df5a0e3-c863-4518-8847-296ad511dc17" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8df5a0e3-c863-4518-8847-296ad511dc17")) {                    Plotly.newPlot(                        "8df5a0e3-c863-4518-8847-296ad511dc17",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Income Group=%{label}<br>Hours_Mean=%{value}<extra></extra>","labels":["High income","Lower middle income","Upper middle income"],"legendgroup":"","name":"","showlegend":true,"values":[6.38375,27.67375,5.946],"type":"pie","hoverinfo":"label+name","textposition":"inside","text":[1,1,1],"textinfo":"label+percent"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"m ...

# %%
df_scmpt.groupby('Income Group')
df_scmpt2 = df_scmpt.groupby(['Income Group']).agg(
    Hours_Mean = ('value', 'mean'))

df_scmpt2
# Out:
#                      Hours_Mean
# Income Group
# High income            53.22500
# Lower middle income    15.38875
# Upper middle income    52.34200

# %%
df_scmpt3=df_scmpt2.reset_index()

# %% [markdown]
# ## Secondary Education grouping by Incomes
#
# This chart cleary shows that the secondary education is mostly dependent on the financial status. As you can see, the Upper middle and high income has the highest percentages of female population who has completed the Secondary education

# %%
fig = px.pie(
    df_scmpt3, values='Hours_Mean', names="Income Group",
  template=list(plotly.io.templates.keys())[5]
)
fig.update_traces(textposition='inside',hoverinfo="label+name")

fig.update_traces(text = df_scmpt3['Income Group'].value_counts(), textinfo = 'label+percent')


indicator_dict = dict(
  font=dict(color="White",size=14),
  x=0.5,
  y=0,
  opacity=0.5,
  showarrow=False,
  text="Percentage of Female population age 15-19 with Secondary education in East Asia & Pacific grouped by Income",
  textangle=0,
  xanchor='center',
  yanchor="top",
  xref="paper",
  yref="paper"
)

fig = fig.add_annotation(indicator_dict)

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5c1b8d28-2b70-49a1-be27-98bd81c4038e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c1b8d28-2b70-49a1-be27-98bd81c4038e")) {                    Plotly.newPlot(                        "5c1b8d28-2b70-49a1-be27-98bd81c4038e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Income Group=%{label}<br>Hours_Mean=%{value}<extra></extra>","labels":["High income","Lower middle income","Upper middle income"],"legendgroup":"","name":"","showlegend":true,"values":[53.225,15.38875,52.342],"type":"pie","hoverinfo":"label+name","textposition":"inside","text":[1,1,1],"textinfo":"label+percent"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"m ...

# %%
df.groupby('Region')
df_region2 = df.groupby(['Region']).agg(
    Hours_Mean = ('value', 'mean'))

df_region2
# Out:
#                             Hours_Mean
# Region
# East Asia & Pacific          20.349365
# Europe & Central Asia        11.913333
# Latin America & Caribbean    14.284933
# Middle East & North Africa   16.325294
# North America                13.353333
# South Asia                   20.247619
# Sub-Saharan Africa           20.326250

# %%
df_region3 = df_region2.reset_index()

# %%
fig = px.pie(
    df_region3, values='Hours_Mean', names="Region",
  template=list(plotly.io.templates.keys())[5]
)
fig.update_traces(textposition='inside',hoverinfo="label+name")
fig.update_traces(text = df_region3['Region'].value_counts(), textinfo = 'label+percent')


indicator_dict = dict(
  font=dict(color="White",size=14),
  x=0.5,
  y=0,
  opacity=0.5,
  showarrow=False,
  text="Comparison between the regions in percentages of female population (age 15-19) education stats",
  textangle=0,
  xanchor='center',
  yanchor="top",
  xref="paper",
  yref="paper"
)

fig = fig.add_annotation(indicator_dict)

# %% [markdown]
# The comparison between the regions in percentages of female population (age 15-19) education stats over the years 2010 to 2015. East Asia & Pacific holds the maximum percentage in completion of the Secondary education for Females in the mentioned year range among the other regions. North America also has a good % of female secondary education. East Asia & Pacific, North America and South Asia holds more than 50% of the secondary education % in the world.

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="26e3086c-68c3-4214-b540-239f4779db7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26e3086c-68c3-4214-b540-239f4779db7e")) {                    Plotly.newPlot(                        "26e3086c-68c3-4214-b540-239f4779db7e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Region=%{label}<br>Hours_Mean=%{value}<extra></extra>","labels":["East Asia & Pacific","Europe & Central Asia","Latin America & Caribbean ","Middle East & North Africa","North America","South Asia","Sub-Saharan Africa "],"legendgroup":"","name":"","showlegend":true,"values":[20.34936507936508,11.913333333333332,14.284933333333331,16.325294117647058,13.353333333333333,20.247619047619047,20.326249999999998],"type":"pie","hoverinfo":"label+name","textposition":"inside","text":[1,1,1,1,1,1,1],"textinfo":"label+percent"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"t ...
